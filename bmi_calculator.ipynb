# %%
from langgraph.graph import StateGraph
from typing import Dict
import invoke

# %%
from typing import TypedDict

#define state

class BMIstate(TypedDict):
    weight_kg: float
    height_m: float
    bmi: float

# %%
def calculate_bmi(state: BMIstate) -> BMIstate:
    weight_kg= state['weight_kg']
    height_m= state['height_m']

    bmi =weight_kg / (height_m * height_m)
    state['bmi'] = round(bmi,2)
    return state

# %%
graph = StateGraph(BMIstate)

graph.add_node('calculate_bmi', calculate_bmi)

graph.add_edge('START', 'calculate_bmi')
graph.add_edge('calculate_bmi', 'END')

workflow = graph.compile()
initial_state = {'weight_kg': 60, 'height_m': 1.8}
final_state = workflow.invoke(initial_state)

print(final_state)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[39], line 8
#       4
#       5 graph.add_edge('START', 'calculate_bmi')
#       6 graph.add_edge('calculate_bmi', 'END')
#       7
# ----> 8 workflow = graph.compile()
#       9 initial_state = {'weight_kg': 60, 'height_m': 1.8}
#      10 final_state = workflow.invoke(initial_state)
#      11
#
# File c:\Users\23ad1\Desktop\langgraph\myenv\Lib\site-packages\langgraph\graph\state.py:1248, in StateGraph.compile(self, checkpointer, cache, store, interrupt_before, interrupt_after, debug, name, transformers)
#    1245 interrupt_after = interrupt_after or []
#    1247 # validate the graph
# -> 1248 self.validate(
#    1249     interrupt=(
#    1250         (interrupt_before if interrupt_before != "*" else []) + interrupt_after
#    1251         if interrupt_after != "*"
#    1252         else []
#    1253     )
#    1254 )
#    1256 # prepare output channels
#    1257 output_channels = (
#    1258     "__root__"
#    1259     if len(self.schemas[self.output_schema]) == 1
#    (...)   1265     ]
#    1266 )
#
# File c:\Users\23ad1\Desktop\langgraph\myenv\Lib\site-packages\langgraph\graph\state.py:1127, in StateGraph.validate(self, interrupt)
#    1125 for source in all_sources:
#    1126     if source not in self.nodes and source != START:
# -> 1127         raise ValueError(f"Found edge starting at unknown node '{source}'")
#    1129 if START not in all_sources:
#    1130     raise ValueError(
#    1131         "Graph must have an entrypoint: add at least one edge from START to another node"
#    1132     )
#
# ValueError: Found edge starting at unknown node 'START'

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[29], line 2
#       1 initial_state = {'weight_kg':60 ,'height_m':180}
# ----> 2 final_state = workflow.invoke(initial_state)
#       3
#       4 print(final_state)
#
# AttributeError: 'function' object has no attribute 'invoke'
