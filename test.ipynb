# %%
from langgraph.graph import StateGraph
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 from langgraph.graph import StateGraphtategraph
#       2
#
# ImportError: cannot import name 'StateGraphtategraph' from 'langgraph.graph' (c:\Users\23ad1\Desktop\langgraph\myenv\Lib\site-packages\langgraph\graph\__init__.py)
